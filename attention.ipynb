# %%
import torch
t = torch.tensor([[1,2,3]])
# use tensor.transpose(-2,-1) instead of K.T!!
# Out:
# tensor([[1, 2, 3]])

# %% [markdown]
# (batch, seq_len, d_model) - standard Attention

# %%
import torch.nn.functional as F

def attention_block(query: torch.Tensor, key: torch.Tensor, values: torch.Tensor) -> torch.Tensor:
    dk = query.shape[-1]
    qk = (query @ key.transpose(-2,-1))/(dk**0.5)
    qk_sm = F.softmax(qk, dim=-1)
    return qk_sm @ values

# %% [markdown]
# (batch, num_heads, seq_len, head_dim) - multi-head attention
#
# - The point of doing so is two-fold:
#     1) Training efficiency. Having single head attention
